# %%
import requests
import json

api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..qkL5O6MD8v75ydcTnV7xE2fgXg8uZTPzHZqkRs3vcT-YBxR8SaOXm_uZtq7ePj8UBwZsuddus06C7DnHZ--us6PCXwxWnZGmstixekFIJ-_D70pOwDdnRpxs4hUy_A-k9uRbmWtOGjQHtNepfzzRYrkwYCg7N0V45C0Sa7148q6Ms9cSNz14NO_XhCpv4q_a_iQ_lSKL1Jwm8ob-9AaEag5x4ZCBRIpYQSch7ol2idrmpml89ptpMbaPVYFaox73uGX3XhhiLeeqnIsQkwyMmQw6BufCGOCCpmZ5sFvEMb3MzKWU40QKvZ0Vn3Q15dwpf-kHiTndgsohTw4TbFMk7lJudaYKMslu9Syk057RRH7sKdevbrDCY5sNXTyzm2rC5DLybxzS9j0WLvisFpLGgCBsep-uQlZQYpG6edL8mKX1Ro71FNOm97zeBK3FkVJ1Pqeg3U7jFoJkK6ZUZ98sp54GAsDL6_ZUv4RmtjjHpZX1d8PiyuavbADxDp92Mef4'

# Set the API endpoint
endpoint = "https://api.lemonsqueezy.com/v1/customers?filter[store_id]=31292"

# Set the headers for the API request
headers = {
        'Accept': 'application/vnd.api+json',
        'Content-Type': 'application/vnd.api+json',
        'Authorization': f'Bearer {api_key}'
    }

print(headers)
# Set the optional parameters (if any)
params = {
  # "page[number]": 1, # The page number to retrieve
  # "page[size]": 10, # The number of customers per page
  #"filter[store_id]": 31292 # The filter by store_id
}

# Make the GET request and get the response
response = requests.get(endpoint, headers=headers, )

# Check if the response is successful
if response.status_code == 200:
  # Parse the response as JSON
  data = response.json()

  # Print the list of customers
  print(data["data"])
else:
  # Print the error message
  print(response.text)
# Out:
# {'Accept': 'application/vnd.api+json', 'Content-Type': 'application/vnd.api+json', 'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..qkL5O6MD8v75ydcTnV7xE2fgXg8uZTPzHZqkRs3vcT-YBxR8SaOXm_uZtq7ePj8UBwZsuddus06C7DnHZ--us6PCXwxWnZGmstixekFIJ-_D70pOwDdnRpxs4hUy_A-k9uRbmWtOGjQHtNepfzzRYrkwYCg7N0V45C0Sa7148q6Ms9cSNz14NO_XhCpv4q_a_iQ_lSKL1Jwm8ob-9AaEag5x4ZCBRIpYQSch7ol2idrmpml89ptpMbaPVYFaox73uGX3XhhiLeeqnIsQkwyMmQw6BufCGOCCpmZ5sFvEMb3MzKWU40QKvZ0Vn3Q15dwpf-kHiTndgsohTw4TbFMk7lJudaYKMslu9Syk057RRH7sKdevbrDCY5sNXTyzm2rC5DLybxzS9j0WLvisFpLGgCBsep-uQlZQYpG6edL8mKX1Ro71FNOm97zeBK3FkVJ1Pqeg3U7jFoJkK6ZUZ98sp54GAsDL6_ZUv4RmtjjHpZX1d8PiyuavbADxDp92Mef4'}
# []

# %%
data["data"]
# Out:
# [{'type': 'orders',
#   'id': '835787',
#   'attributes': {'store_id': 31292,
#    'customer_id': 805854,
#    'identifier': '5c4e96d4-1806-4e1c-bee7-da4018daa729',
#    'order_number': 3,
#    'user_name': 'Luke',
#    'user_email': 'like@gmail.com',
#    'currency': 'USD',
#    'currency_rate': '1.00000000',
#    'subtotal': 999,
#    'discount_total': 0,
#    'tax': 0,
#    'total': 999,
#    'subtotal_usd': 999,
#    'discount_total_usd': 0,
#    'tax_usd': 0,
#    'total_usd': 999,
#    'tax_name': None,
#    'tax_rate': '0.00',
#    'status': 'paid',
#    'status_formatted': 'Paid',
#    'refunded': False,
#    'refunded_at': None,
#    'subtotal_formatted': '$9.99',
#    'discount_total_formatted': '$0.00',
#    'tax_formatted': '$0.00',
#    'total_formatted': '$9.99',
#    'first_order_item': {'order_id': 835787,
#     'product_id': 82658,
#     'variant_id': 86776,
#     'product_name': 'Membership',
#     'variant_name': 'Monthly',
#     'price': 999,
# ...

# %%
customers["jsonapi"]
# Out:
# {'version': '1.0'}

# %%
customers["data"]
# Out:
# []

# %%
import requests
import json

api_url = "https://api.lemonsqueezy.com"

def get(route, data=None):
    headers = {
        'Accept': 'application/vnd.api+json',
        'Content-Type': 'application/vnd.api+json',
        'Authorization': f'Bearer {api_key}'
    }
    response = requests.get(f'{api_url}/{route}', headers=headers, params=data)
    return response.json()

# Fetching a specific store's details
store_id = "31292"  # Replace with the actual store id
store = get(f'v1/stores/{store_id}')
print(json.dumps(store, indent=4))
# Out:
# {
#     "jsonapi": {
#         "version": "1.0"
#     },
#     "links": {
#         "self": "https://api.lemonsqueezy.com/v1/stores/31292"
#     },
#     "data": {
#         "type": "stores",
#         "id": "31292",
#         "attributes": {
#             "name": "AI Learning Hub",
#             "slug": "ailearninghub",
#             "domain": "ailearninghub.lemonsqueezy.com",
#             "url": "https://ailearninghub.lemonsqueezy.com",
#             "avatar_url": "https://eu.ui-avatars.com/api/?name=AI+Learning+Hub&length=1&background=FF7D52&color=fff&size=64&rounded=true",
#             "plan": "free",
#             "country": "PL",
#             "country_nicename": "Poland",
#             "currency": "USD",
#             "total_sales": 0,
#             "total_revenue": 0,
#             "thirty_day_sales": 0,
#             "thirty_day_revenue": 0,
#             "created_at": "2023-06-08T17:39:44.000000Z",
#             "updated_at": "2023-06-08T17:39:44.000000Z"
#         },
# ...

# %%
import requests
import json

api_url = "https://api.lemonsqueezy.com"

def get(route, data=None):
    headers = {
        'Accept': 'application/vnd.api+json',
        'Content-Type': 'application/vnd.api+json',
        'Authorization': f'Bearer {api_key}'  # Replace with your actual API key
    }
    response = requests.get(f'{api_url}/{route}', headers=headers, params=data)
    return response.json()

# Fetching a specific store's subscriptions
store_id = "31292"  # Replace with the actual store id
subscriptions = get(f'v1/orders?filter[user_email]=like@gmail.com')
print(json.dumps(subscriptions, indent=4))
# Out:
# {
#     "meta": {
#         "page": {
#             "currentPage": 1,
#             "from": 1,
#             "lastPage": 1,
#             "perPage": 10,
#             "to": 1,
#             "total": 1
#         }
#     },
#     "jsonapi": {
#         "version": "1.0"
#     },
#     "links": {
#         "first": "https://api.lemonsqueezy.com/v1/orders?filter%5Buser_email%5D=like%40gmail.com&page%5Bnumber%5D=1&page%5Bsize%5D=10&sort=-createdAt",
#         "last": "https://api.lemonsqueezy.com/v1/orders?filter%5Buser_email%5D=like%40gmail.com&page%5Bnumber%5D=1&page%5Bsize%5D=10&sort=-createdAt"
#     },
#     "data": [
#         {
#             "type": "orders",
#             "id": "835787",
#             "attributes": {
#                 "store_id": 31292,
#                 "customer_id": 805854,
#                 "identifier": "5c4e96d4-1806-4e1c-bee7-da4018daa729",
#                 "order_number": 3,
#                 "user_name": "Luke",
# ...

# %%
import requests
import json

api_url = "https://api.lemonsqueezy.com"

def get(route, data=None):
    headers = {
        'Accept': 'application/vnd.api+json',
        'Content-Type': 'application/vnd.api+json',
        'Authorization': f'Bearer {api_key}'  # Replace with your actual API key
    }
    response = requests.get(f'{api_url}/{route}', headers=headers, params=data)
    return response.json()

# Fetching a specific store's subscriptions
store_id = "31292"  # Replace with the actual store id
subscriptions = get(f'v1/subscriptions/74921/store')
print(json.dumps(subscriptions, indent=4))
# Out:
# {
#     "jsonapi": {
#         "version": "1.0"
#     },
#     "links": {
#         "related": "https://api.lemonsqueezy.com/v1/subscriptions/74921/store",
#         "self": "https://api.lemonsqueezy.com/v1/subscriptions/74921/relationships/store"
#     },
#     "data": {
#         "type": "stores",
#         "id": "31292",
#         "attributes": {
#             "name": "AI Learning Hub",
#             "slug": "ailearninghub",
#             "domain": "ailearninghub.lemonsqueezy.com",
#             "url": "https://ailearninghub.lemonsqueezy.com",
#             "avatar_url": "https://eu.ui-avatars.com/api/?name=AI+Learning+Hub&length=1&background=FF7D52&color=fff&size=64&rounded=true",
#             "plan": "free",
#             "country": "PL",
#             "country_nicename": "Poland",
#             "currency": "USD",
#             "total_sales": 0,
#             "total_revenue": 0,
#             "thirty_day_sales": 0,
#             "thirty_day_revenue": 0,
# ...

# %%
import requests
import json

api_url = "https://api.lemonsqueezy.com"

def get(route, data=None):
    headers = {
        'Accept': 'application/vnd.api+json',
        'Content-Type': 'application/vnd.api+json',
        'Authorization': f'Bearer {api_key}'
    }
    response = requests.get(f'{api_url}/{route}', headers=headers, params=data)
    return response.json()

# Fetching a specific store's details
store_id = "31292"  # Replace with the actual store id
store = get(f'v1/subscriptions')
print(json.dumps(store, indent=4))
# Out:
# {
#     "meta": {
#         "page": {
#             "currentPage": 1,
#             "from": 1,
#             "lastPage": 1,
#             "perPage": 10,
#             "to": 3,
#             "total": 3
#         }
#     },
#     "jsonapi": {
#         "version": "1.0"
#     },
#     "links": {
#         "first": "https://api.lemonsqueezy.com/v1/subscriptions?page%5Bnumber%5D=1&page%5Bsize%5D=10&sort=-createdAt",
#         "last": "https://api.lemonsqueezy.com/v1/subscriptions?page%5Bnumber%5D=1&page%5Bsize%5D=10&sort=-createdAt"
#     },
#     "data": [
#         {
#             "type": "subscriptions",
#             "id": "74921",
#             "attributes": {
#                 "store_id": 31292,
#                 "customer_id": 805854,
#                 "order_id": 835787,
#                 "order_item_id": 804919,
#                 "product_id": 82658,
#                 "variant_id": 86776,
#                 "product_name": "Membership",
# ...

# %%
import requests
import json

api_url = "https://api.lemonsqueezy.com"

def get(route, data=None):
    headers = {
        'Accept': 'application/vnd.api+json',
        'Content-Type': 'application/vnd.api+json',
        'Authorization': f'Bearer {api_key}'
    }
    response = requests.get(f'{api_url}/{route}', headers=headers, params=data)
    return response.json()

# Fetching a specific store's details
store_id = "31292"  # Replace with the actual store id
store = get(f'v1/subscriptions/74921/order?filter[user_email]=pihalami.atedeto@rungel.net')
print(json.dumps(store, indent=4))
# Out:
# {
#     "jsonapi": {
#         "version": "1.0"
#     },
#     "links": {
#         "related": "https://api.lemonsqueezy.com/v1/subscriptions/74921/order",
#         "self": "https://api.lemonsqueezy.com/v1/subscriptions/74921/relationships/order"
#     },
#     "data": null
# }

# %% [markdown]
# # -----------------------

# %%
from appwrite.client import Client
from appwrite.services.users import Users
from appwrite.id import ID

client = Client()

(client
  .set_endpoint('https://cloud.appwrite.io/v1') # Your API Endpoint
  .set_project('648488bd63e196b61344') # Your project ID
  .set_key('') # Your secret API key
  .set_self_signed() # Use only on dev mode with a self-signed SSL cert
)

users = Users(client)

result = users.create(ID.unique(), 'email@example.com', 'password')
# Out:
# c:\Users\dkornas\Documents\GitHub\ailearninghub\website_env\lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'cloud.appwrite.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\dkornas\Documents\GitHub\ailearninghub\website_env\lib\site-packages\appwrite\client.py:97, in Client.call(self, method, path, headers, params)
#      86 response = requests.request(  # call method dynamically https://stackoverflow.com/a/4246075/2299554
#      87     method=method,
#      88     url=self._endpoint + path,
#    (...)
#      94     verify=(not self._self_signed),
#      95 )
# ---> 97 response.raise_for_status()
# ...

# %%
# Out:
# c:\Users\dkornas\Documents\GitHub\ailearninghub\website_env\lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'cloud.appwrite.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\dkornas\Documents\GitHub\ailearninghub\website_env\lib\site-packages\appwrite\client.py:97, in Client.call(self, method, path, headers, params)
#      86 response = requests.request(  # call method dynamically https://stackoverflow.com/a/4246075/2299554
#      87     method=method,
#      88     url=self._endpoint + path,
#    (...)
#      94     verify=(not self._self_signed),
#      95 )
# ---> 97 response.raise_for_status()
# ...
